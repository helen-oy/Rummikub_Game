# %%
pip install pygame
# Out:
# Requirement already satisfied: pygame in /Users/helen/anaconda3/lib/python3.11/site-packages (2.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#references
# fonts from dafont.com
#https://www.pygame.org/
#https://youtu.be/_D-_OmR36Pk?si=L24aue5dqPrN-_5D

import pygame, sys, threading
from pygame.locals import *

pygame.init()


    
#create game window
SCREEN_WIDTH =1280
SCREEN_HEIGHT = 720

#define colors
white = (255, 255, 255)
green = (0, 255, 0)
red = (255, 0, 0)
purple =(125, 0, 125)

#create Work
work = 1000000

#Loading bg
loading_bg =pygame.image.load("Loading Bar Background .png")
loading_bg = pygame.transform.scale_by(loading_bg, 0.8) #the extra line of code added worked a bit
loading_bg_rect = loading_bg.get_rect(topleft=(300,400), width=600, height=40)

#Loading bg and variables
loading_bar =pygame.image.load("Loading Bar .png")
loading_bar = pygame.transform.scale_by(loading_bar, 0.8) #the extra line of code
loading_bar_rect = loading_bar.get_rect(topleft=(305,385),width=600, height=40)
loading_finished = False
loading_progress = 0
loading_bar_width = 8

def doWork():
    global loading_finished, loading_progress
    
    for i in range(work):
        math_equation =  523600/788456 * 88996
        loading_progress = i
    loading_finished = True
    
#define fonts
font =pygame.font.Font('Milk And Honey.ttf', 100)
regularFont = pygame.font.Font('Sweet Vusstain.ttf', 65)

#Resume text to show start of game after loading:
finished = regularFont.render("Start Game", True, "purple")
finished_rect = finished.get_rect(center=(640, 360))

#Thread
threading.Thread(target=doWork).start()

#screens and captions
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("First display page")
pygame.display.set_caption("Loading bar")


#define fonts
font =pygame.font.Font('Milk And Honey.ttf', 100)
regularFont = pygame.font.Font('Sweet Vusstain.ttf', 65)

#define clock
clock = pygame.time.Clock()
fps = 60

IMAGE = pygame.image.load('UoNLogo.png')
IMAGE = pygame.transform.scale_by(IMAGE, 0.4)

#create a text surface object
text =font.render("Rummikub", True, red)

#create rectangular object for text
textRect = text.get_rect()

#set the center of the rectangular object 
textRect.center =(SCREEN_WIDTH//2,SCREEN_HEIGHT//2)


#game loop
while True:

    screen.fill((0, 0, 230))

    screen.blit(text, textRect)

    screen.blit(IMAGE,(0,0))
    

    if not loading_finished:
        screen.fill((0, 0, 230))

        screen.blit(text, textRect)
        clock.tick(fps)
        screen.blit(IMAGE,(0,0))
    
        loading_bar_width = loading_progress/ work * 720
        
        loading_bar = pygame.transform.scale(loading_bar, (int(loading_bar_width), 167))
        loading_bar_rect = loading_bar.get_rect(topleft=(305,385),width=600, height=40)  

        screen.blit(loading_bg, loading_bg_rect)
        screen.blit(loading_bar, loading_bar_rect)
        
    else:
        screen.fill((0, 0, 230))
        
        screen.blit(IMAGE,(0,0))
        
        screen.blit(finished, finished_rect)
        
    #event handler
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_ESCAPE:             
                  pygame.quit() 
                
        elif event.type == pygame.MOUSEMOTION:
            pygame.display.set_caption(str(event.pos))
                   
        
        pygame.display.update()              
        clock.tick(fps)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/helen/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#references
# fonts from dafont.com
#https://www.pygame.org/
#https://youtu.be/_D-_OmR36Pk?si=L24aue5dqPrN-_5D

import pygame, sys, threading
from pygame.locals import *
from button import Button

pygame.init()

#create game window
SCREEN_WIDTH =1100
SCREEN_HEIGHT = 800

#define colors
white = (255, 255, 255)
green = (0, 255, 0)
red = (255, 0, 0)
purple =(125, 0, 125)
wine =(240, 0, 50)

#define rectangle
x = 200
y = 450


#define fonts
font =pygame.font.Font('Milk And Honey.ttf', 100)
regularFont = pygame.font.Font('Sweet Vusstain.ttf', 65)

#screens and captions
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("First display page")



#define fonts
font =pygame.font.Font('Milk And Honey.ttf', 100)
regularFont = pygame.font.Font('Sweet Vusstain.ttf', 65)

#define clock
clock = pygame.time.Clock()
fps = 60

IMAGE = pygame.image.load('UoNLogo.png')
IMAGE = pygame.transform.scale_by(IMAGE, 0.4)

#create a text surface object
text =font.render("Rummikub", True, red)

#create rectangular object for text
textRect = text.get_rect()

#set the center of the rectangular object 
textRect.center =(SCREEN_WIDTH//2,SCREEN_HEIGHT//2)


#Resume text to show start of game after loading:
finished = regularFont.render("Start Game", True, "purple")
finished_rect = finished.get_rect(center=(550, 400))




def run_game():
    
    pygame.display.set_caption("initialize game")
     
    
    #game loop
    while True:
        
        PLAY_MOUSE_POS = pygame.mouse.get_pos()
        screen.fill((0, 0, 230))
        pygame.display.flip()
    
        screen.blit(IMAGE,(0,0))
            
        screen.blit(text, textRect)
        
    
            #event handler
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                return
                pygame.quit()
                
            if event.type == pygame.MOUSEBUTTONDOWN:
                    if play_back.checkInput(PLAY_MOUSE_POS):
                            run_game()
            elif event.type == pygame.MOUSEMOTION:
                pygame.display.set_caption(str(event.pos))
               
            
            x = 200
            pygame.draw.circle(screen, pygame.Color('yellow'), (x,y), 10)
            pygame.display.flip()
            
            x += 1 if x < 840 else x == 840
            
            clock.tick(fps)
            
            
            
        pygame.time.wait(20)
        

def start_game():
    
    pygame.display.set_caption("start_game")
    
    while True:
        
        PLAY_MOUSE_POS = pygame.mouse.get_pos()
        
        screen.fill((0, 0, 230))
        
        regularFont = pygame.font.SysFont('Sweet Vusstain.ttf', 65)
        title = regularFont.render("Start Game", True, "purple")
        start_button = regularFont.render("Play", True, "purple")
        screen.blit(title, (SCREEN_WIDTH/2 - title.get_width()/2, SCREEN_HEIGHT/2 - title.get_height()/2))
        screen.blit(start_button, (SCREEN_WIDTH/2 - start_button.get_width()/2, SCREEN_HEIGHT/2 + start_button.get_height()/2))
        pygame.display.update()
        
        play_back = Button(image=None, pos=(550, 200), 
                            text_input="Start Game", font=get_font(50), base_color="White", hovering_color="purple")

        play_back.changeColor(PLAY_MOUSE_POS)
        play_back.update(screen)
                           
        for event in pygame.event.get():
                if event.type == QUIT:
                    pygame.quit()
                    sys.exit()
                        
                if event.type == pygame.MOUSEBUTTONDOWN:
                    if play_back.checkInput(PLAY_MOUSE_POS):
                           main_menu()
                   
                           
        pygame.display.update()

def get_font(size):
    return pygame.font.Font('Sweet Vusstain.ttf', size)
        
def main_menu():#Main menu screen
    pygame.display.set_caption("Menu")
                           
    while True:
        screen.fill((0, 0, 230))
        menu_mouse_pos = pygame.mouse.get_pos()
        
        menu_text = get_font(50).render("MAIN MENU", True,(240, 0, 50))
        menu_rect = menu_text.get_rect(center=(550, 100))
        
        play_button = Button(image =pygame.image.load("rectPLAY.png"), pos =(550,250), text_input ="PLAY", font = get_font(50), base_color = (240, 0, 50), hovering_color= "white")
        options_button  = Button(image =pygame.image.load("rectOPTIONS.png"), pos =(550,400), text_input ="OPTIONS", font =get_font(50), base_color = (240, 0, 50), hovering_color= "white")
        quit_button = Button(image =pygame.image.load("rectQUIT.png"), pos =(550,550), text_input ="QUIT", font =get_font(50), base_color = (240, 0, 50), hovering_color= "white")
        
        
        screen.blit(menu_text, menu_rect)
        
        for button in [play_button, options_button, quit_button]:
            button.changeColor(menu_mouse_pos)
            button.update(screen)
            
        for event in pygame.event.get():
                if event.type == QUIT:
                    pygame.quit()
                    sys.exit()
                if event.type == pygame.MOUSEBUTTONDOWN:
                    if PLAY_BUTTON.checkInput(menu_mouse_pos):
                        play()
                    if OPTIONS_BUTTON.checkInput(menu_mouse_pos):
                        options()
                    if QUIT_BUTTON.checkInput(menu_mouse_pos):
                        pygame.quit()
                        sys.exit()
                           
        pygame.display.update()
        
        
        
run_game()        
start_game()        
main_menu()
                           
                    
                           
    
        
                           

        
        
        
            
        
                
            
    
        

        
                

pygame.quit()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 185
#     179                         sys.exit()
#     181         pygame.display.update()
# --> 185 run_game()
#     186 start_game()
#     187 main_menu()
#
# Cell In[1], line 90, in run_game()
#      87     pygame.quit()
#      89 if event.type == pygame.MOUSEBUTTONDOWN:
# ---> 90         if play_back.checkInput(PLAY_MOUSE_POS):
#      91                 run_game()
#      92 elif event.type == pygame.MOUSEMOTION:
#
# NameError: name 'play_back' is not defined

# %%
pip install pygame

# %%
text =font.render("Rummikub", True, red)
        
textRect = text.get_rect()
textRect.center = (SCREEN_WIDTH/2 - text.get_width()/2, SCREEN_HEIGHT/2 + text.get_height()/2)
screen.blit(text, textRect)
